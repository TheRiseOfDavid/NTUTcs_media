# %%
# !ln -f -s /content/drive/MyDrive/NTUT/'大二下- 資工多媒體技術與應用'/'軌跡預測' /drive
# !ls /drive
# Out:
# datasets	   log.log  SGAN_04171525_with_model.pt  軌跡預測
# evaluate_model.py  sgan     train.py			 軌跡預測.ipynb

# %%
# %cd /drive/
# Out:
# /content/drive/MyDrive/NTUT/大二下- 資工多媒體技術與應用/軌跡預測

# %%
# !pip install torch==1.4.0

# %%
pip install attrdict

# %%
# !python train.py --dataset_name '04171525' --num_epoch 5
# Out:
# [WARNING: train.py:  173]: Initializing train dataset: 04171525
# [INFO: train.py:  175]: Initializing val dataset
# [INFO: train.py:  396]: There are 44 iterations in total, 8.90625 iterations per epoch
# [INFO: train.py:  456]: Restoring from checkpoint /content/drive/My Drive/NTUT/大二下- 資工多媒體技術與應用/軌跡預測/SGAN_04171525_with_model.pt
# [INFO: train.py:  553]: Starting epoch 1, 2021-06-10 04:28:14.549407
# [INFO: train.py:  584]: t = 1 / 44
# [INFO: train.py:  586]:   [D] D_data_loss: 1.386
# [INFO: train.py:  586]:   [D] D_total_loss: 1.386
# [INFO: train.py:  589]:   [G] G_discriminator_loss: 0.693
# [INFO: train.py:  589]:   [G] G_l2_loss_rel: 0.112
# [INFO: train.py:  589]:   [G] G_total_loss: 0.805
# [INFO: train.py:  553]: Starting epoch 2, 2021-06-10 04:28:51.439132
# [INFO: train.py:  553]: Starting epoch 3, 2021-06-10 04:29:28.845040
# [INFO: train.py:  553]: Starting epoch 4, 2021-06-10 04:30:06.337905
# [INFO: train.py:  584]: t = 21 / 44
# ...

# %%
# !python evaluate_model.py --model_path "./SGAN_04171525_with_model.pt"
# Out:
# Model path:  ./SGAN_04171525_with_model.pt
# Dataset: 04171525, Pred Len: 8, ADE: 0.24, FDE: 0.42, Time: 16.26296 (s), Counts: 6900, Avg time: 0.00236
